# %%
import pandas as pd
from collections import deque
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_excel('demands.xlsx',index_col = 0)
summary = pd.read_excel('summary.xlsx', index_col = 0)

# %%
summary
# Out:
#              Total Demand over 50 Weeks (units)  \
# Part Number
# B15                                         248
# C17                                         696
# D20                                         148
# D25                                         243
# E26                                         275
# F35                                         118
#
#              Average Weekly Demand (units)  Current Backlog (units)  \
# Part Number
# B15                                   4.96                       58
# C17                                  13.92                       34
# D20                                   2.96                       15
# D25                                   4.86                       40
# E26                                   5.50                       14
# F35                                   2.36                        3
#
#              Revenue Per Unit  Material Cost Per Unit
# Part Number
# ...

# %%
B15 = data[["B15"]]
reversed_B15 = B15.iloc[::-1]
reversed_B15.index = np.arange(1, len(reversed_B15) + 1)

# %%
# pip install darts --user

# %%
from darts import TimeSeries
from darts.models import ExponentialSmoothing
from darts.models import Prophet
import datetime

# %%
# reversed_B15.index = pd.to_datetime(reversed_B15.index, origin=pd.Timestamp('2021-01-01'), unit = 'D')   
# reversed_B15

# %%
series_B15 = TimeSeries.from_dataframe(reversed_B15)

# %%
train, val = series_B15.split_before(pd.Timestamp('2021-02-20'))
model = ExponentialSmoothing()
model.fit(series_B15)
prediction_ES_B15 = model.predict(50)

series_B15.plot(label='Actual')
prediction_ES_B15.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# /Users/ericzhou/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
# train, val = series_B15.split_before(pd.Timestamp('2021-02-20'))
model_Prophet = Prophet()
model_Prophet.fit(series_B15)
prediction_Prophet_B15 = model_Prophet.predict(50)

series_B15.plot(label='Actual')
prediction_Prophet_B15.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# from darts.models import AutoARIMA

# model_aarima = AutoARIMA()
# model_aarima.fit(series_B15)
# prediction_aarima = model_aarima.predict(50)

# series_B15.plot(label='Actual')
# prediction_aarima.plot(label='Forecast', lw=3)
# plt.legend()

# %%
C17 = data[["C17"]]
reversed_C17 = C17.iloc[::-1]
reversed_C17.index = np.arange(1, len(reversed_C17) + 1)

reversed_C17.index = pd.to_datetime(reversed_C17.index, origin=pd.Timestamp('2021-01-01'), unit='D') 

series_C17 = TimeSeries.from_dataframe(reversed_C17)

model_Prophet_C17 = Prophet()
model_Prophet_C17.fit(series_C17)
prediction_Prophet_C17 = model_Prophet_C17.predict(50)

series_C17.plot(label='Actual')
prediction_Prophet_C17.plot(label='Forecast', lw=3)
plt.legend()

model_ES_C17 = ExponentialSmoothing()
model_ES_C17.fit(series_C17)
prediction_ES_C17 = model_ES_C17.predict(50)

series_C17.plot(label='Actual')
prediction_ES_C17.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model_ES_C17 = ExponentialSmoothing()
model_ES_C17.fit(series_C17)
prediction_ES_C17 = model_ES_C17.predict(50)

series_C17.plot(label='Actual')
prediction_ES_C17.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# /Users/ericzhou/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
D20 = data[["D20"]]
reversed_D20 = D20.iloc[::-1]
reversed_D20.index = np.arange(1, len(reversed_D20) + 1)

reversed_D20.index = pd.to_datetime(reversed_D20.index, origin=pd.Timestamp('2021-01-01'), unit='D') 

series_D20 = TimeSeries.from_dataframe(reversed_D20)

# model_Prophet_D20 = Prophet()
# model_Prophet_D20.fit(series_D20)
# prediction_Prophet_D20 = model_Prophet_D20.predict(50)

# series_D20.plot(label='Actual')
# prediction_Prophet_D20.plot(label='Forecast', lw=3)
# plt.legend()

model_ES_D20 = ExponentialSmoothing()
model_ES_D20.fit(series_D20)
prediction_ES_D20 = model_ES_D20.predict(50)

series_D20.plot(label='Actual')
prediction_ES_D20.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# /Users/ericzhou/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
D25 = data[["D25"]]
reversed_D25 = D25.iloc[::-1]
reversed_D25.index = np.arange(1, len(reversed_D25) + 1)

reversed_D25.index = pd.to_datetime(reversed_D25.index, origin=pd.Timestamp('2021-01-01'), unit='D') 

series_D25 = TimeSeries.from_dataframe(reversed_D25)

# model_Prophet_D20 = Prophet()
# model_Prophet_D20.fit(series_D20)
# prediction_Prophet_D20 = model_Prophet_D20.predict(50)

# series_D20.plot(label='Actual')
# prediction_Prophet_D20.plot(label='Forecast', lw=3)
# plt.legend()

model_ES_D25 = ExponentialSmoothing()
model_ES_D25.fit(series_D25)
prediction_ES_D25 = model_ES_D25.predict(50)

series_D25.plot(label='Actual')
prediction_ES_D25.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# /Users/ericzhou/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
E26 = data[["E26"]]
reversed_E26 = E26.iloc[::-1]
reversed_E26.index = np.arange(1, len(reversed_E26) + 1)

reversed_E26.index = pd.to_datetime(reversed_E26.index, origin=pd.Timestamp('2021-01-01'), unit='D') 

series_E26 = TimeSeries.from_dataframe(reversed_E26)

model_Prophet_E26 = Prophet()
model_Prophet_E26.fit(series_E26)
prediction_Prophet_E26 = model_Prophet_E26.predict(50)

series_E26.plot(label='Actual')
prediction_Prophet_E26.plot(label='Forecast', lw=3)
plt.legend()

# model_ES_E26 = ExponentialSmoothing()
# model_ES_E26.fit(series_E26)
# prediction_ES_E26 = model_ES_E26.predict(50)

# series_E26.plot(label='Actual')
# prediction_ES_E26.plot(label='Forecast', lw=3)
# plt.legend()
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
F35 = data[["F35"]]
reversed_F35 = F35.iloc[::-1]
reversed_F35.index = np.arange(1, len(reversed_F35) + 1)

reversed_F35.index = pd.to_datetime(reversed_F35.index, origin=pd.Timestamp('2021-01-01'), unit='D') 

series_F35 = TimeSeries.from_dataframe(reversed_F35)

# model_Prophet_F35 = Prophet()
# model_Prophet_F35.fit(series_F35)
# prediction_Prophet_F35 = model_Prophet_F35.predict(50)

# series_F35.plot(label='Actual')
# prediction_Prophet_F35.plot(label='Forecast', lw=3)
# plt.legend()

model_ES_F35 = ExponentialSmoothing()
model_ES_F35.fit(series_F35)
prediction_ES_F35 = model_ES_F35.predict(50)

series_F35.plot(label='Actual')
prediction_ES_F35.plot(label='Forecast', lw=3)
plt.legend()
# Out:
# /Users/ericzhou/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
TS_Fcst_total = pd.concat([prediction_ES_B15.pd_dataframe(), 
           prediction_ES_C17.pd_dataframe(), 
           prediction_ES_D20.pd_dataframe(),
           prediction_ES_D25.pd_dataframe(),
           prediction_ES_E26.pd_dataframe(),
           prediction_ES_F35.pd_dataframe()],axis=1)

# %%
TS_Fcst_total['Future_Weeks'] = np.arange(len(TS_Fcst_total))
TS_Fcst_total['Future_Weeks'] = TS_Fcst_total['Future_Weeks']+1

# %%
# TS_Fcst_total.set_index('Future_Weeks', inplace=True)
TS_Fcst_total.to_csv('TS_Fcst_total.csv')
